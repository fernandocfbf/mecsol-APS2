# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
k = 1
alpha = 1
T = 3
Q = 80
t_final = 5
delta_x = 0.5
delta_y = delta_x
delta_t = 0.05#(delta_x**2)/(4*k) - 0.0125
tempo = np.arange(0, t_final, delta_t)
c = np.zeros((61,61))
c_futuro = np.zeros((61,61))

# %%
for t in tempo:
  for x in range(0, 60):
    for y in range(0, 60):
      dcdx = (alpha*(c[y][x+1] - c[y][x-1])/(delta_x*2))
      dcdy = 0#((alpha*math.sin(x*(math.pi/5)))*(c[x][y+1] - c[x][y-1])/(2*delta_y))
      d2cdx2 = k*((c[y][x+1] - 2*c[y][x] + c[y][x-1])/(delta_x**2))
      d2cdy2 = k*((c[y+1][x] - 2*c[y][x] + c[y-1][x])/(delta_y**2))
      if(t < 2 and x == 30 and y == 30):
        q = Q/(delta_x*delta_y)
      else:
        q = 0
      c_futuro[y][x] = c[y][x] + delta_t*(-dcdx - dcdy + d2cdx2 + d2cdy2 + q)
      if(c_futuro[y][x] < 0):
        c_futuro[y][x] = 0
      if(y == 0):
        c_futuro[0][x] = c_futuro[1][x]
      elif(y == 60):
        c_futuro[60][x] = c_futuro[59][x]
      elif(x == 0):
        c_futuro[y][0] = c_futuro[y][1]
      elif(x == 60):
        c_futuro[y][60] = c_futuro[y][59]
  c = np.copy(c_futuro)

# %%
plt.imshow(c_futuro, vmin=0, vmax=1, extent=(0,30,0,30))
print(c_futuro[40][40])
# plt.gca().invert_xaxis()
# plt.gca().invert_yaxis()
plt.colorbar()
plt.show()
print(c_futuro)
# Out:
# 0.6036247404637634
# [[6.15830342e-15 8.19753148e-15 2.01968480e-14 ... 3.04994448e-08
#   1.39551979e-08 0.00000000e+00]
#  [8.19753148e-15 1.08332042e-14 2.62592832e-14 ... 3.94982366e-08
#   1.82239580e-08 0.00000000e+00]
#  [1.69646710e-14 2.21132298e-14 5.26172297e-14 ... 7.87727372e-08
#   3.66220693e-08 0.00000000e+00]
#  ...
#  [1.60334087e-14 2.08417483e-14 4.93946467e-14 ... 7.38743078e-08
#   3.44049280e-08 0.00000000e+00]
#  [5.76332193e-15 7.55252825e-15 1.80637494e-14 ... 2.70816015e-08
#   1.25722719e-08 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]]
