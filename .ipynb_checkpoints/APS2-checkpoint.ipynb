# %% [markdown]
# ## APS2 - TRANSFERÊNCIA DE CALOR E MECÂNICA DOS SÓLIDOS
# Grupo: Fernando Fincatti, Gabriela Moreno, Lais Nascimento, Theo Barbara;
#
# ---

# %% [markdown]
# ### Importando as bibliotecas
# ---

# %%
import numpy as np
from math import *
import matplotlib.pyplot as plt

# %% [markdown]
# ### Declarando varíaveis
# ---

# %%
n = 2              #nº do grupo
k = 1              #m^2/s
alpha = 1          #m/s
T = 3              #s
Q = 100            #kg/ms
lx = 30            #m
ly = 20            #m
a = int(n/1.4)     #xxx
b = int(60/(n+5))  #xxx
tempo = 10*T       #s
delta_t = 1e-3     #s
delta_x = 1        #m
delta_y = delta_x  #m

# %%
k = 1              #m^2/s
alpha = 1          #m/s
T = 2              #s
Q = 80            #kg/ms
lx = 30            #m
ly = 30            #m
a = 15*2     #xxx
b = 15*2  #xxx
tempo = 5       #s
delta_t = 0.05     #s
delta_x = 0.5        #m
delta_y = delta_x  #m

# %%
#teste de convergência
(delta_t/delta_x**2) < (1/4*k)
# Out:
# True

# %%
#número de nós em x
dimensao_x = int((lx/delta_x)) + 1

#número de nós em y
dimensao_y = int((ly/delta_y)) + 1

#steps no tempo
dimensao_z = int(tempo/delta_t)

print("Dimensão x: {0}\nDimensão y: {1}\nDimensão z: {2}".format(dimensao_x,dimensao_y,dimensao_z))
# Out:
# Dimensão x: 61
# Dimensão y: 61
# Dimensão z: 100

# %% [markdown]
# ## Funções de auxílio
# ---

# %%
def equacao_concentracao(x, y, c_mais_i_ant, c_menos_i_ant, c_mais_j_ant, c_menos_j_ant, c_ij_ant, t):
    
    #calcula o primeiro termo
    primeiro_termo = -1*(c_mais_i_ant - c_menos_i_ant)/(2*delta_x)
    
    #calcula o segundo termo
    segundo_termo = 0*(c_mais_j_ant - c_menos_j_ant)/(2*delta_y)
    
    #calcula o terceiro termo
    terceiro_termo = k*(c_mais_i_ant - 2*c_ij_ant + c_menos_i_ant)/(delta_x**2)
    
    #calcula o quarto termo
    quarto_termo = k*(c_mais_j_ant - 2*c_ij_ant + c_menos_j_ant)/(delta_y**2)
    
    # Para a posição (a,b) para tempos menores de 3 segundos tem derramamento Q. !=0
    if x == a and y == b and t < 3:
        quinto_termo = Q/(delta_x*delta_y)
    
    # Se não obdece essas condições tem que desconsiderar o quinto termo que colocamos na função?
    else:
        quinto_termo = 0
    
    #calcula a resposta final
    resposta = delta_t*(primeiro_termo + segundo_termo + terceiro_termo + quarto_termo + quinto_termo) + c_ij_ant
    
    return resposta

# %% [markdown]
# ## Inicializando a placa
# ---

# %%
#inicializa as condições do rio
rio = np.zeros((dimensao_x, dimensao_y, dimensao_z))

# %%
rio;

# %% [markdown]
# ## Calculando a temperatura
# ---

# %%
tempo_atual = 1  #tempo
i = 1            #linhas
j = 0            #colunas

while(tempo_atual < dimensao_z):
    
    i = 1 #reinicia as colunas
    
    while(i < dimensao_x-1):
        
        j = 1 #reinicia as linhas
        
        while(j < dimensao_y-1):
            
            #calcula dispersão do poluente
            rio[i, j, tempo_atual] = equacao_concentracao(i, j, rio[i+1, j, tempo_atual-1], rio[i-1, j, tempo_atual-1], rio[i, j+1, tempo_atual-1], rio[i, j-1, tempo_atual-1], rio[i, j, tempo_atual-1], tempo_atual)
            
            j += 1
        i += 1
    tempo_atual += 1

# %% [markdown]
# ### Condição de contorno

# %%
tempo_atual = 1  #tempo

while(tempo_atual < dimensao_z):
    j = 0
    
    while(j < dimensao_y-1):
        rio[0, j, tempo_atual] = rio[1, j, tempo_atual]
        j += 1 
    
    tempo_atual += 1
print("terminei 1/4")
# Out:
# terminei 1/4

# %%
tempo_atual = 1  #tempo
while(tempo_atual < dimensao_z):
    j = 0
    while(j < dimensao_y-1):
        rio[dimensao_x-1, j, :] = rio[dimensao_x-2, j, tempo_atual]
        j += 1
        
    tempo_atual += 1
print("terminei 2/4")
# Out:
# terminei 2/4

# %%
tempo_atual = 1  #tempo
while(tempo_atual < dimensao_z):
    i=0
    while(i < dimensao_x-1):
        rio[i, 0, tempo_atual] = rio[i, 1, tempo_atual]
        
        i += 1 
    
    
    tempo_atual += 1
print("terminei 3/4")
# Out:
# terminei 3/4

# %%
tempo_atual = 1  #tempo
while(tempo_atual < dimensao_z):
    i=0
    while(i < dimensao_x-1):
        rio[i, dimensao_y-1, tempo_atual] = rio[i, dimensao_y-2, tempo_atual]
        i += 1
    tempo_atual += 1
print("terminei 4/4")
# Out:
# terminei 4/4

# %%
plt.imshow(rio[:,:,dimensao_z-1])
plt.colorbar()
plt.xlim(0,60)
plt.ylim(0,60)
plt.show()

# %%
rio[40][40][dimensao_z-1]
# Out:
# 0.07364999938679911
